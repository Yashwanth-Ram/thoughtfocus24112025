# %%
dbutils.widgets.combobox("top_n_records2",
                         choices=["10", "20", "50", "100"],
                         defaultValue="10",
                         label="Top N Records")

# %%
dbutils.widgets.get("top_n_records")

# %%
dbutils.widgets.dropdown("top_n_records1",
                         choices=["1", "2", "5", "10"],
                         defaultValue="1",
                         label="Top N Records")

# %%
dbutils.widgets.multiselect(name='user_input',
                           defaultValue="2g",
                           choices=['1g', '2g', '3g'],
                           label='Technology')

# %%
dbutils.widgets.get("user_input")

# %%
dbutils.widgets.remove("top_n_records1")

# %%
dbutils.widgets.removeAll()

# %% [markdown]
# ## Pre-requisites

# %% [markdown]
# ### Load users_001.csv into a dataframe

# %%
df = spark.read.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv", header=True, inferSchema=True)
df.display()

# %% [markdown]
# ### Create a deltaTable

# %%
# %sql

USE CATALOG quickstart_catalog;
 
CREATE TABLE quickstart_schema.users_delta (
  id INT,
  name STRING,
  dob DATE,
  email STRING,
  gender STRING,
  country STRING,
  region STRING,
  city STRING,
  asset INT,
  marital_status STRING
);
 
DESCRIBE EXTENDED quickstart_schema.users_delta;

# %% [markdown]
# ### Loading data into delta table

# %%
df.write.mode("overwrite").saveAsTable("quickstart_schema.users_delta")

# %% [markdown]
# ### Read Delta table

# %%
spark.read.table("quickstart_schema.users_delta").display()

# %% [markdown]
# ### Transaction history

# %% [markdown]
# ### Using Delta table API

# %% [markdown]
# #### Python API

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forName(spark, "quickstart_schema.users_delta")
delta_table.history().display()

# %% [markdown]
# #### SQL

# %%
# %sql

DESCRIBE FORMATTED quickstart_catalog.quickstart_schema.users_delta;

# %% [markdown]
# ### transaction 03

# %%
from pyspark.sql.functions import col
df.filter(col("country")=="India").write.mode("overwrite").saveAsTable("quickstart_schema.users_delta")

# %% [markdown]
# ### Read a specific version

# %% [markdown]
# #### Python API

# %%
spark.read.option("versionAsOf",2).table("quickstart_schema.users_delta").display()

# %% [markdown]
# #### SQL

# %%
# %sql
SELECT * from quickstart_schema.users_delta VERSION AS OF 3 LIMIT 4;

# %% [markdown]
# ### TimeTravel

# %%
# %sql

USE CATALOG quickstart_catalog;

# %%
# %sql

SELECT * FROM quickstart_schema.users_delta TIMESTAMP AS OF '2025-11-27T13:47:17' LIMIT 10;
